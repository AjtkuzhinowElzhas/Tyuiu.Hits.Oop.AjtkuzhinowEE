// %% [markdown]
// <h1 style="color:DodgerBlue">Индивидуальный проект</h1>

// %% [markdown]
// <h2 style="color:DodgerBlue">Название проекта:</h2>Информация о студентах
//
//
// ----
//
// ### Вариант задания 2

// %% [markdown]
// <h2 style="color:DodgerBlue">Описание проекта:</h2>
//
// ----
//
// Описание задачи:
// Создать базовый класс Student в C#, который будет представлять информацию о
// студентах. На основе этого класса разработать 2-3 производных класса,
// демонстрирующих принципы наследования и полиморфизма. В каждом из классов
// должны быть реализованы новые атрибуты и методы, а также переопределены
// некоторые методы базового класса для демонстрации полиморфизма.
//
// Требования к базовому классу Student:
// • Атрибуты: Имя (Name), Возраст (Age), Курс (Course).
// • Методы:
// o GetInfo(): метод для получения информации о студенте в виде строки.
// o Study(): метод для вывода сообщения о том, что студент учится.
// o TakeExam(): метод для вывода сообщения о сдаче экзамена.
//
// Требования к производным классам:
// 1. Студент бакалавриата (BachelorStudent): Должен содержать дополнительные
// атрибуты, такие как Специальность (Specialty). Метод Study() должен быть
// переопределен для добавления информации о специальности при изучении
// предмета.
// 2. Студент магистратуры (MasterStudent): Должен содержать дополнительные
// атрибуты, такие как Научный руководитель (ScientificAdvisor).
// Метод TakeExam() должен быть переопределен для добавления
// информации о научном руководителе при сдаче экзамена.
// 3. Аспирант (PhDStudent) (если требуется третий класс): Должен содержать
// дополнительные атрибуты, такие как Тема диссертации (DissertationTopic).
// Метод Study() должен быть переопределен для добавления информации о
// теме диссертации при изучении предмета.
//
// #### Дополнительное задание
// Добавьте к сущестующим классам конструктора классов с использованием гетторов и сетторов и реализуйте взаимодействие объектов между собой

// %% [markdown]
// <h2 style="color:DodgerBlue">Реализация:</h2>
//
// ----

// %%
public class Student
{
    private string name;
    private int age;
    private int course;

    public string Name
    {
        get { return name; }
        set { name = value; }
    }

    public int Age
    {
        get { return age; }
        set
        {
            if (value >= 0)
                age = value;
            else
                throw new ArgumentOutOfRangeException("Возраст не может быть отрицательным!");
        }
    }

    public int Course
    {
        get { return course; }
        set
        {
            if (value >= 1)
                course = value;
            else
                throw new ArgumentOutOfRangeException("Курс должен быть не меньше 1!");
        }
    }

    public static int TotalStudents { get; private set; } = 0;

    public Student(string name, int age, int course)
    {
        Name = name;
        Age = age;
        Course = course;
        TotalStudents++;
    }

    public virtual string GetInfo()
    {
        return $"Имя: {Name}, Возраст: {Age}, Курс: {Course}";
    }

    public virtual void Study()
    {
        Console.WriteLine($"{Name} учится на {Course} курсе.");
    }

    public virtual void TakeExam()
    {
        Console.WriteLine($"{Name} сдает экзамен.");
    }

    public void InteractWith(Student other)
    {
        Console.WriteLine($"{Name} общается с {other.Name}.");
        other.Study();
    }

    public static void DisplayTotalStudents()
    {
        Console.WriteLine($"Общее количество студентов: {TotalStudents}");
    }
}

public class BachelorStudent : Student
{
    private string specialty;

    public string Specialty
    {
        get { return specialty; }
        set { specialty = value; }
    }

    public BachelorStudent(string name, int age, int course, string specialty)
        : base(name, age, course)
    {
        Specialty = specialty;
    }

    public override void Study()
    {
        Console.WriteLine($"{Name} учится на {Course} курсе бакалавриата по специальности \"{Specialty}\".");
    }

    public override string GetInfo()
    {
        return base.GetInfo() + $", Специальность: {Specialty}";
    }
}

public class MasterStudent : Student
{
    private string scientificAdvisor;

    public string ScientificAdvisor
    {
        get { return scientificAdvisor; }
        set { scientificAdvisor = value; }
    }

    public MasterStudent(string name, int age, int course, string scientificAdvisor)
        : base(name, age, course)
    {
        ScientificAdvisor = scientificAdvisor;
    }

    public override void TakeExam()
    {
        Console.WriteLine($"{Name} сдает экзамен под руководством научного руководителя {ScientificAdvisor}.");
    }

    public override string GetInfo()
    {
        return base.GetInfo() + $", Научный руководитель: {ScientificAdvisor}";
    }
}

public class PhDStudent : Student
{
    private string dissertationTopic;

    public string DissertationTopic
    {
        get { return dissertationTopic; }
        set { dissertationTopic = value; }
    }

    public PhDStudent(string name, int age, int course, string dissertationTopic)
        : base(name, age, course)
    {
        DissertationTopic = dissertationTopic;
    }

    public override void Study()
    {
        Console.WriteLine($"{Name} работает над диссертацией на тему \"{DissertationTopic}\" и учится на {Course} курсе аспирантуры.");
    }

    public override string GetInfo()
    {
        return base.GetInfo() + $", Тема диссертации: {DissertationTopic}";
    }
}

var students = new List<Student>
{
    new BachelorStudent("Иван Петров", 20, 3, "Программная инженерия"),
    new MasterStudent("Анна Сидорова", 24, 1, "Проф. Смирнов"),
    new PhDStudent("Дмитрий Иванов", 28, 2, "Искусственный интеллект в образовании")
};

Console.WriteLine("=== ИНФОРМАЦИЯ О СТУДЕНТАХ ===\n");

foreach (var student in students)
{
    Console.WriteLine("--- " + student.GetType().Name + " ---");
    Console.WriteLine(student.GetInfo());
    student.Study();
    student.TakeExam();
    Console.WriteLine();
}

Console.WriteLine("=== ПОЛИМОРФИЗМ В ДЕЙСТВИИ ===\n");

Student[] studentArray = new Student[]
{
    new BachelorStudent("Елена Козлова", 21, 2, "Экономика"),
    new MasterStudent("Олег Новиков", 23, 2, "Доц. Васильева"),
    new PhDStudent("Мария Соколова", 26, 3, "Нейронные сети")
};

foreach (var student in studentArray)
{
    Console.WriteLine($"Студент: {student.Name}");
    student.Study();
}

Console.WriteLine("\n=== ВЗАИМОДЕЙСТВИЕ СТУДЕНТОВ ===\n");

students[0].InteractWith(students[1]);
students[2].InteractWith(students[0]);

Console.WriteLine();
Student.DisplayTotalStudents();
// Out:
// === ИНФОРМАЦИЯ О СТУДЕНТАХ ===
//
// --- BachelorStudent ---
// Имя: Иван Петров, Возраст: 20, Курс: 3, Специальность: Программная инженерия
// Иван Петров учится на 3 курсе бакалавриата по специальности "Программная инженерия".
// Иван Петров сдает экзамен.
//
// --- MasterStudent ---
// Имя: Анна Сидорова, Возраст: 24, Курс: 1, Научный руководитель: Проф. Смирнов
// Анна Сидорова учится на 1 курсе.
// Анна Сидорова сдает экзамен под руководством научного руководителя Проф. Смирнов.
//
// --- PhDStudent ---
// Имя: Дмитрий Иванов, Возраст: 28, Курс: 2, Тема диссертации: Искусственный интеллект в образовании
// Дмитрий Иванов работает над диссертацией на тему "Искусственный интеллект в образовании" и учится на 2 курсе аспирантуры.
// Дмитрий Иванов сдает экзамен.
//
// === ПОЛИМОРФИЗМ В ДЕЙСТВИИ ===
//
// Студент: Елена Козлова
// Елена Козлова учится на 2 курсе бакалавриата по специальности "Экономика".
// Студент: Олег Новиков
// Олег Новиков учится на 2 курсе.
// Студент: Мария Соколова
// Мария Соколова работает над диссертацией на тему "Нейронные сети" и учится на 3 курсе аспирантуры.
//
// === ВЗАИМОДЕЙСТВИЕ СТУДЕНТОВ ===
//
// Иван Петров общается с Анна Сидорова.
// Анна Сидорова учится на 1 курсе.
// Дмитрий Иванов общается с Иван Петров.
// Иван Петров учится на 3 курсе бакалавриата по специальности "Программная инженерия".
//
// Общее количество студентов: 6
